# %%
name=input("Enter name: ")
age=int(input("Enter age: "))
# Out:
# Enter name: sana
# Enter age: 23

# %%
print("Hello")
# Out:
# Hello

# %%
print(10+20)
# Out:
# 30

# %%
print("10+20")
# Out:
# 10+20

# %%
x=10
print(x)
# Out:
# 10

# %%
x=5
x=10
print(x)
# Out:
# 10

# %%
name="John"
print("name: "+name)
# Out:
# name: John

# %%
a=2
b=4
c=a+b
print(c)
# Out:
# 6

# %%
age=22
mark=70.5
name="Anu"
passed=True
print(type(age))
print(type(mark))
print(type(name))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name=
